# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/raw/train.csv")

# %%
fireplace_col = [col for col in df.columns if 'Fireplace' in col]
df_fireplace = df[fireplace_col]
print(df_fireplace.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fireplaces   1460 non-null   int64
#  1   FireplaceQu  770 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 22.9+ KB
# None

# %%
df_fireplace.isnull().sum()
# Out:
# Fireplaces       0
# FireplaceQu    690
# dtype: int64

# %%
# Nếu Fireplaces = 0 thì FireplaceQu = 'No Fireplace'
df_fireplace['FireplaceQu'] = df_fireplace.apply(lambda row: 'No Fireplace' if row['Fireplaces'] == 0 else row['FireplaceQu'], axis=1)
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_32396\2797786443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fireplace['FireplaceQu'] = df_fireplace.apply(lambda row: 'No Fireplace' if row['Fireplaces'] == 0 else row['FireplaceQu'], axis=1)

# %%
df_fireplace.isnull().sum()
# Out:
# Fireplaces     0
# FireplaceQu    0
# dtype: int64
